# %% [markdown]
# #**Değişkenler**
# Verileri saklamamızı sağlayan yapılardır. Diyelim ki kullanıcı bilgisayara bilgi girdi, girilen bilgiyi ben program da işlemek istersem o bilgiyi bir değişkenin içinde saklarım.

# %%
#Bir değişken oluşturalım
#Değişken adımı ve soyadımı saklasın
adsoyad = "Mikari Wiwiniku"
yas = 13
print(adsoyad) #Değişkenler print yazılmadığı sürece ekranda gösterilmez!
print(yas)
# Out:
# Mikari Wiwiniku
# 13

# %% [markdown]
# #**Değişkenlerin Özellikleri**
# 1. Değişkenler amacına göre isimlendirilir
# 2. İsim verilirken Türkçe karakter kullanılmaz
# 3. Değişkenler, sayı, metin, kesirli sayı, Doğru/Yanlış değerlerini alabilir

# %%
#Farklı Değişken Türleri
arabanin_ismi = "Tesla" #Metin -> Stirng (str) demektir.
arabanin_motoru = 400 # Sayı -> Integer (int) demektir
arabanin_yuksekligi = 123.9 #Yükseklik -> Float (f) demektir
arabanin_genisligi = 95.9 #Ondalıklı Sayı -> Double (d) demektir
araba_calisiyor_mu = True #Doğru/Yanlış -> Boolean (bool) demektir
araba_pahali_mi = True #Doğru/Yanlış -> Boolean (bool) demektir
araba_guzel_mi = False #Doğru/Yanlış -> Boolean (bool) demektir
print(arabanin_ismi, arabanin_motoru, arabanin_yuksekligi, arabanin_genisligi, araba_calisiyor_mu, araba_pahali_mi, araba_guzel_mi)
# Out:
# Tesla 400 123.9 95.9 True True False

# %% [markdown]
# #**Ödevler**
# 1. Tarihi bir kişiliğin hayatını seçin
# 2. kişinin bilgilerini değişkenlerin içine yazın. Ama değişkenlerin adını amacına uygun yazın!
# * Örneğin; ad_soyad = "Mustafa Kemal Atatürk" vb. şeklinde
# 3. Girmeniz gereken (oluşturmanız gereken değişkenler) şunlardır:
#    a. Ad Soyad
#    b. Doğduğu yıl
#    c. öldüğü Yıl (Varsa - olmayabilir)
#    d. Erkek mi Kadın mı?
#    e. Şuan hayatta mı? (Doğru/Yanlış)
#    f. Mesleği
#    g. Kısa bir şekilde önemli kişiliğini açıkla (2 cümle)
# 5. Girilen değişkenleri print ile ekrana yazdırın.

# %%
Not = int(input("Sınvandan aldığınız puan"))
if Not <=50:
  print("sınavdan kaldınız")
else:
  print("sınavdan geçtiniz")
# Out:
# Sınvandan aldığınız puan76
# sınavdan geçtiniz
