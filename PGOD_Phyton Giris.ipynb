# %% [markdown]
# #Çalıştığım Sunucunun Bilgileri

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 10:09:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# #Phyton İlk Kod
# Phyton'a giriş dersinde ilk olarak bilgisayara yazı yazdırıyoruz! ^^

# %%
print("Hello!!!^^")
# Out:
# Hello!!!^^

# %%
print(2+8)
# Out:
# 10

# %%
print(str(2)+""+str(8))
# Out:
# 28

# %% [markdown]
# **String**: Metin değişkenleri anlmaına gelir. "" (çift tırnak) işareti arasına yazılır. Sayıları metine dönüştürürken str(sayı) içine yazarız
#
# **Integer**: Sayı değişkenleri anlamına gelir. Sadece sayının kendisi yazılır. Sayıya çevirmek için int(sayı) yazarız.

# %%
print(len("matematik"))
# Out:
# 9

# %% [markdown]
# **Not-1**: Sayıları metinlere çevirebilirim ancak metinleri sayıya çeviremem.
#
# **Not-2**: Metinlerin harf sayısını (uzunluğunu) öğrenebilirim.
#
# **len()**: Parantez içine çift tırnakla bir yazı yazarsam bana harf sayısını verir.

# %%
print(23+9)
print(23-9)
print(23*9)
print(23/9)
# Out:
# 32
# 14
# 207
# 2.5555555555555554

# %%
print((23+9),(23-9),(23*9),(23/9))
print((23+9)+(23-9)+(23*9)+(23/9))
# Out:
# 32 14 207 2.5555555555555554
# 255.55555555555554

# %%
print("Merhaba ben", "Mikari","Yapay zekasıyım<3" )
print("Size muhteşem bir atom bombası vericem^^" + "umarım seversiniz^^<3 "+"UwU")
# Out:
# Merhaba ben Mikari Yapay zekasıyım<3
# Size muhteşem bir atom bombası vericem^^umarım seversiniz^^<3 UwU

# %%
print("Mikari'den günün menüsü^^: \n" + "İnsan eti,Patates püresi,Göz ve Beyin çorbası, Kulak içi tatlısı ve AYRAN")
# Out:
# Mikari'den günün menüsü^^:
# İnsan eti,Patates püresi,Göz ve Beyin çorbası, Kulak içi tatlısı ve AYRAN

# %%
print("Merhaba ben Mikari Wiwiniku,siz beni Beril olarak tanıyorsunuz bu yüzden size bu halimi tanıtıcam (Mikari halimi)")
print("ilk olarak 1374 yaşındayım ama sizin yaşınızda 13")
print("aslında uzay boşluğundan gelen uzaylı bir kediyim ama insan formum da kahve rengi sa.lı siyah gözlü bir...şeyim")
print("insan yemeyi ve kedileri severim^^")
# Out:
# Merhaba ben Mikari Wiwiniku,siz beni Beril olarak tanıyorsunuz bu yüzden size bu halimi tanıtıcam (Mikari halimi)
# ilk olarak 1374 yaşındayım ama sizin yaşınızda 13
# aslında uzay boşluğundan gelen uzaylı bir kediyim ama insan formum da kahve rengi sa.lı siyah gözlü bir...şeyim
# insan yemeyi ve kedileri severim^^

# %%
print((32*2),(64/2),(26+38),(64-38))
# Out:
# 64 32.0 64 26

# %%
print("anay, \n"+ "babay, \n"+"abay ve \n" "bne")
# Out:
# anay,
# babay,
# abay ve
# bne

# %%
print(8)
# Out:
# 8

# %%
print("Haşmet Dayı restorantları Menü:Kelle Beyin çorbası, Göz Kalbin Aynasıdır gözlü kalpli et sote, Burun tatlısı , ayak parmaklı turşu mezesi ve ayran")
# Out:
# Haşmet Dayı restorantları Menü:Kelle Beyin çorbası, Göz Kalbin Aynasıdır gözlü kalpli et sote, Burun tatlısı , ayak parmaklı turşu mezesi ve ayran
